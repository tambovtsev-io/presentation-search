# %%
# %load_ext autoreload
# %autoreload 2
import sys, os
sys.path.append(os.path.abspath("../../"))
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from src import (
    SingleSlidePipeline,
    display_chain_outputs
)
from src.chains.chains import FindPdfChain
from src.config import Config
from src.chains.prompts import JsonH1AndGDPrompt

# %%
config = Config()

llm = config.model_config.load_vsegpt(model="vis-openai/gpt-4o-mini")

pipe_structured = FindPdfChain() | SingleSlidePipeline(llm=llm, vision_prompt=JsonH1AndGDPrompt())

# %%
pdf_path = "ЯиП_Энергетический_переход_Вызовы_и_возможности_для_России"

out = pipe_structured.invoke(dict(
    pdf_path=pdf_path,
    page_num=4,
))
display_chain_outputs(out["chain_outputs"])
# Out:
# Structured Analysis:
# Text Content:
#     Основной заголовок: "Потрясения последних лет уже кардинально изменили
#      мир и повлияют на энергетические рынки будущего"
#
#     Подзаголовок: "Зависимость цепочек поставок и инвестиций в энергетике
#     от геополитических событий"
#
#     Текстовые блоки:
#     1. "Мир, каким мы его знали":
#     - Экономия масштаба в производстве и ресурсоснабжении
#     - Эффективные глобальные цепочки поставок
#     - Потребление «золотым миллиардом»
#     - Акционерная стоимость превыше всего
#
#     2. "Мир, к которому мы идем":
#     - Разрывы привычных цепочек поставок, многополярность экономического
#     ландшафта
#     - Ориентация на снижение рисков через построение суверенных
#     энергетических экосистем
#     - Расширение практики приоритизации дружественных отношений в
#     энергетических сделках
#     - Акцент на доступную и устойчивую энергию
#
#     Источник: "Federal Reserve Bank of New York; Bloomberg; открытые
#     источники"
# Visual Content:
#     Линейный график с двумя осями Y:
#     - Черная линия: Индекс давления на глобальные цепочки поставок
#     - Желтая линия: Глобальный индекс цен на энергию
#
#     Ось X: Временная шкала 2000-2023
#
#     Аннотации важных событий:
#     - Мировой экономический кризис
#     - «Арабская весна»
#     - BREXIT
#     - Начало торговой войны США и Китая
#     - Эпидемия COVID-19
#     - Начало СВО
#     - Палестинский конфликт
#
#     Используются различные паттерны линий для доступности.
#     Логотип "Яков и Партнёры" в правом нижнем углу.
#     Фирменная цветовая схема с синим и желтым цветами.
# General Description:
#   Topic Overview:
#       Тема: Влияние геополитических событий на энергетические рынки
#       Цель: Показать взаимосвязь между глобальными событиями, цепочками
#       поставок и ценами на энергоносители
#       Ключевая информация: Сравнение прошлого и будущего состояния
#       энергетических рынков
#   Conclusions And Insights:
#       Потрясения последних лет значительно изменили структуру энергетических
#        рынков.
#       Важность адаптации к новым условиям и рискам в цепочках поставок.
#       Необходимость перехода к устойчивым и доступным источникам энергии.
#
#       Наблюдаются значительные изменения в индексах.
#       Сравнение с предыдущими периодами показывает тренды.
#       Выявлены потенциальные последствия для бизнеса.
#   Layout And Composition:
#       Левая часть (60%): график и заголовок.
#       Правая часть (40%): текстовые блоки на черном фоне.
#       Присутствуют фирменные элементы оформления.

# %%
from pprint import pprint

print(out["chain_outputs"]["parsed_output"].model_dump_json(indent=2))
# Out:
# {
#   "text_content": "Основной заголовок: \"Потрясения последних лет уже кардинально изменили мир и повлияют на энергетические рынки будущего\"\n\nПодзаголовок: \"Зависимость цепочек поставок и инвестиций в энергетике от геополитических событий\"\n\nТекстовые блоки:\n1. \"Мир, каким мы его знали\":\n- Экономия масштаба в производстве и ресурсоснабжении\n- Эффективные глобальные цепочки поставок\n- Потребление «золотым миллиардом»\n- Акционерная стоимость превыше всего\n\n2. \"Мир, к которому мы идем\":\n- Разрывы привычных цепочек поставок, многополярность экономического ландшафта\n- Ориентация на снижение рисков через построение суверенных энергетических экосистем\n- Расширение практики приоритизации дружественных отношений в энергетических сделках\n- Акцент на доступную и устойчивую энергию\n\nИсточник: \"Federal Reserve Bank of New York; Bloomberg; открытые источники\"",
#   "visual_content": "Линейный график с двумя осями Y:\n- Черная линия: Индекс давления на глобальные цепочки поставок\n- Желтая линия: Глобальный индекс цен на энергию\n\nОсь X: Временная шкала 2000-2023\n\nАннотации важных событий:\n- Мировой экономический кризис\n- «Арабская весна»\n- BREXIT\n- Начало торговой войны США и Китая\n- Эпидемия COVID-19\n- Начало СВО\n- Палестинский конфликт\n\nИспользуются различные паттерны линий для доступности.\nЛоготип \"Яков и Партнёры\" в правом нижнем углу.\nФирменная цветовая схема с синим и желтым цветами.",
#   "general_description": {
#     "topic_overview": "Тема: Влияние геополитических событий на энергетические рынки\nЦель: Показать взаимосвязь между глобальными событиями, цепочками поставок и ценами на энергоносители\nКлючевая информация: Сравнение прошлого и будущего состояния энергетических рынков",
#     "conclusions_and_insights": "Потрясения последних лет значительно изменили структуру энергетических рынков.\nВажность адаптации к новым условиям и рискам в цепочках поставок.\nНеобходимость перехода к устойчивым и доступным источникам энергии.\n\nНаблюдаются значительные изменения в индексах.\nСравнение с предыдущими периодами показывает тренды.\nВыявлены потенциальные последствия для бизнеса.",
#     "layout_and_composition": "Левая часть (60%): график и заголовок.\nПравая часть (40%): текстовые блоки на черном фоне.\nПрисутствуют фирменные элементы оформления."
#   }
# }

# %%
pdf_path = "ЯиП_Энергетический_переход_Вызовы_и_возможности_для_России"

out = pipe_structured.invoke(dict(
    pdf_path=pdf_path,
    page_num=5,
))
display_chain_outputs(out["chain_outputs"])
# Out:
# Structured Analysis:
# Text Content:
#     Заголовок: "Спрос на первичную энергию в мире будет расти за счет
#     роста населения и подушевого потребления в развивающихся странах"
#
#     Подзаголовок: "Население, млрд чел."
#
#     Данные:
#     - 2000: 5,1 (развивающиеся страны: 1,0)
#     - 2010: 5,9 (развивающиеся страны: 1,1)
#     - 2023: 6,9 (развивающиеся страны: 1,1)
#     - 2050: 8,6 (развивающиеся страны: 2,1)
#
#     Подзаголовок: "Подушевое потребление первичной энергии, ГДж"
#
#     Данные:
#     - 2000: 212
#     - 2010: 200
#     - 2023: 188
#     - 2050: 158
#
#     Комментарии:
#     01. Прогнозируемый рост населения к 2050 г. составит более 20%, его
#     обеспечит преимущественно развивающиеся страны.
#     02. В развитых странах будет наблюдаться эффект замещения
#     исключительно видов топлива электричеством, в том числе ВИЭ.
#     03. В развивающихся странах эффект замещения будет ограниченным,
#     поэтому спрос на энергию и ее потребление будут увеличиваться за счет
#     индустриализации развивающихся регионов и расширения потребительских
#     возможностей.
# Visual Content:
#     График с двумя осями: на горизонтальной оси указаны годы (2000, 2010,
#     2023, 2050), на вертикальной оси - население (млрд чел.) и подушевое
#     потребление энергии (ГДж).
#
#     Столбчатая диаграмма показывает население развитых и развивающихся
#     стран с выделением подушевого потребления энергии. Столбцы для
#     развивающихся стран окрашены в черный цвет, для развитых - в желтый.
#
#     Линия на графике показывает изменение подушевого потребления энергии с
#      2000 по 2050 год, с аннотациями для каждого года. Логотип "Яков и
#     Партнёры" расположен в правом нижнем углу. Используются
#     высококонтрастные цвета для улучшения восприятия информации.
# General Description:
#   Topic Overview:
#       Тема: Спрос на первичную энергию в мире
#       Цель: Показать влияние роста населения и подушевого потребления на
#       спрос на энергию
#       Ключевая информация: Прогнозы по населению и потреблению энергии в
#       развивающихся странах.
#   Conclusions And Insights:
#       Основные выводы:
#       - Ожидается рост населения в развивающихся странах, что приведет к
#       увеличению спроса на первичную энергию.
#       - Подушевое потребление энергии в развивающихся странах будет
#       увеличиваться, несмотря на эффект замещения в развитых странах.
#       - Важно учитывать влияние индустриализации на спрос на энергию.
#   Layout And Composition:
#       Слайд разделен на две основные части: график занимает левую часть,
#       текстовые комментарии расположены справа. Используется четкая иерархия
#        элементов, с акцентом на визуализацию данных.

# %%
pdf_path = "ЯиП_Энергетический_переход_Вызовы_и_возможности_для_России"
page_num = 23

out = pipe_structured.invoke(dict(
    pdf_path=pdf_path,
    page_num=page_num,
))
display_chain_outputs(out["chain_outputs"])
# Out:
# Structured Analysis:
# Text Content:
#     Заголовок: "Обеспечение внутреннего спроса через создание
#     инфраструктуры, особенно в удаленных регионах"
#
#     Подзаголовок: "Стоимость электроэнергии, одноставочный тариф для
#     населения, 2023 г."
#
#     Энергетические проекты:
#     - Сейчас в Арктике и ДФО наблюдается дефицит электроэнергетических
#     мощностей, который может превысить 1500 МВт к 2029 г.
#     - Запланированные проекты в сфере ВИЭ и атомной генерации смогут
#     частично покрыть спрос на электроэнергии.
#     - Атом: суммарная мощность вводимых АСММ – 105 МВт к 2028 г.
#     - ВИЭ: около 750 МВт солнечной генерации в Забайкалье к 2029 г. и
#     более 1 ГВт в ветроэнергетике в Китае, вдобавок новых мощностей ГЭС на
#      Камчатке с общей мощностью более 2 ГВт.
#
#     Комментарии:
#     - Удаленные регионы являются полигоном для развития новых технологий,
#     неконкурентоспособных в центральной части России.
#     - Газификация прибрежных территорий станет более рентабельной после
#     запуска круглогодичной навигации по СМП.
#     - Развитие АСММ и ВИЭ (где это уместно) позволит избежать высоких
#     затрат на поставку топлива.
#     - Сахалин потенциально может стать площадкой для международной
#     кооперации в сфере технологий чистой энергетики в виду статуса
#     специальной экономической зоны и географической близости к странам
#     АТР.
# Visual Content:
#     На слайде представлена карта России, где цветовая кодировка обозначает
#      стоимость электроэнергии по регионам. Цветовая шкала варьируется от
#     светло-зеленого (1 руб./кВтч) до темно-красного (более 8 руб./кВтч).
#     На карте выделены регионы с дефицитом электроэнергии, а также
#     обозначены ключевые энергетические проекты. Легенда карты расположена
#     в верхней части слайда, а текстовые блоки с описанием проектов и
#     комментариями находятся справа от карты. Логотип "Яков и Партнёры"
#     размещен внизу справа.
# General Description:
#   Topic Overview:
#       Тема: Обеспечение внутреннего спроса на электроэнергию в удаленных
#       регионах.
#       Цель: Показать текущие проблемы и планы по развитию энергетической
#       инфраструктуры.
#       Ключевая информация: Дефицит мощностей и запланированные проекты в
#       сфере ВИЭ и атомной энергетики.
#   Conclusions And Insights:
#       Основные выводы:
#       - Дефицит электроэнергии в удаленных регионах требует срочных мер.
#       - Запланированные проекты могут частично решить проблему, но требуют
#       времени и инвестиций.
#       - Удаленные регионы могут стать центрами для новых технологий и
#       устойчивого развития.
#   Layout And Composition:
#       Слайд разделен на две основные части: карта занимает левую часть (60%
#       площади), текстовые блоки расположены справа (40%). Используется
#       четкая цветовая кодировка для визуализации данных, что облегчает
#       восприятие информации. Логотип компании добавляет элементы брендинга.

# %%
pdf_path = "SP_Навигатор_по_мерам_гос_поддержки_"
page_num = 8

out = pipe_structured.invoke(dict(
    pdf_path=pdf_path,
    page_num=page_num,
))
display_chain_outputs(out["chain_outputs"])
# Out:
# Structured Analysis:
# Text Content:
#     Заголовок: "Проектное финансирование промышленного производства (2/3)"
#
#     Подзаголовок: "На данный момент ФРП реализует 7 программ, направленных
#      на поддержку развития компонентной базы, цифровизации предприятий,
#     повышения производительности труда и др."
#
#     Стилизация текста:
#     - Заголовок выделен жирным шрифтом и крупным размером
#     - Подзаголовок имеет меньший размер шрифта, но также выделен
#
#     Многоязычные элементы:
#     - Проектное финансирование (Project Financing)
#     - Производительность труда (Labor Productivity)
# Visual Content:
#     Таблица с 7 колонками и 5 строками, представляющая программы
#     кредитования ФРП.
#
#     Структура таблицы:
#     - Основные программы кредитования
#     - Сумма займа, млн руб.
#     - Процентная ставка
#     - Максимальный срок займа
#     - Общий бюджет проекта, млн руб.
#     - Софинансирование
#     - Специальные условия
#
#     Ключевые данные:
#     - Программа "КОМПЛЕКТУЮЩИЕ ИЗДЕЛИЯ" с суммой займа от 100 до 1000 млн
#     руб. и ставкой 3% при банковской гарантии.
#     - Программа "АВТОКОМПОНЕНТЫ" с максимальным сроком займа 7 лет.
#
#     Таблица имеет четкие границы между ячейками, с выделением заголовков
#     колонок жирным шрифтом. Цветовая схема таблицы нейтральная, с акцентом
#      на важные данные.
# General Description:
#   Topic Overview:
#       Тема: Проектное финансирование промышленного производства
#       Цель: Представить детальную информацию о программах кредитования ФРП
#       Ключевая информация: Условия и параметры 5 основных программ
#       кредитования для промышленных предприятий
#   Conclusions And Insights:
#       Основные выводы:
#       - ФРП предлагает разнообразные программы с льготными условиями
#       кредитования
#       - Процентные ставки варьируются от 3% до 5%
#       - Сроки кредитования достигают 7 лет
#       - Суммы займов находятся в широком диапазоне от 5 млн до 5 млрд рублей
#       - Каждая программа имеет специфические требования по софинансированию
#       и целевым показателям
#   Layout And Composition:
#       Слайд имеет четкую иерархическую структуру:
#       - Заголовок и подзаголовок в верхней части
#       - Основная таблица занимает центральную часть слайда
#       - Брендинговые элементы расположены по периметру
#       - Использовано эффективное распределение пространства для большого
#       объема данных

# %%
pdf_path = "4. Бурыгин Сила нетворкинга 17.10"
page_num = 7

out = pipe_structured.invoke(dict(
    pdf_path=pdf_path,
    page_num=page_num,
))
display_chain_outputs(out["chain_outputs"])
# Out:
# Structured Analysis:
# Text Content:
#     Основной заголовок: "Боюсь".
#
#     Стилизация текста: Заголовок выполнен крупным шрифтом, черного цвета,
#     что придает ему акцент и делает его легко читаемым на фоне.
# Visual Content:
#     На слайде изображен желтый персонаж с большими глазами и выражением
#     страха, сидящий на полу. Он держит над головой книгу с красной
#     обложкой, что создает комичный эффект. Фон слайда светло-лавандового
#     цвета, что контрастирует с ярким желтым цветом персонажа и красной
#     книгой.
# General Description:
#   Topic Overview:
#       Тема: Эмоции и страхи. Цель: Передать чувство страха через визуальные
#       и текстовые элементы. Ключевая информация: Персонаж выражает страх,
#       что может быть связано с чтением или изучением.
#   Conclusions And Insights:
#       Основное сообщение: Страх может быть вызван различными факторами,
#       включая обучение и новые знания. Персонаж олицетворяет эту эмоцию.
#   Layout And Composition:
#       Слайд имеет простую композицию: заголовок расположен в верхней части,
#       а изображение персонажа занимает центральную часть. Используется много
#        свободного пространства, что делает слайд легким для восприятия.
