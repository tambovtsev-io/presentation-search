# %%
# %load_ext autoreload
# %autoreload 2
import sys, os
sys.path.append(os.path.abspath("../../"))
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from src import (
    PresentationAnalysis,
    SlideAnalysis,
    Config,
    display_chain_outputs
)
from src.chains.chains import FindPdfChain
from src.config.output_formatting import display_presentation_analysis, display_presentation_from_file
from src.testing_utils import EchoLLM
import logging
from src.config.output_formatting import display_search_result_page
from src.rag import ChromaSlideStore, create_slides_database

config = Config()

# %%
collection_name = "pres1"
embeddings = config.embedding_config.load_vsegpt()
embeddings = config.embedding_config.load_openai()
storage = ChromaSlideStore(collection_name="pres1", embedding_model=embeddings)

# %%
results = storage.search_query_presentations(
    "Презентация про космонавтов",
)
display_search_result_page(results[0].best_slide)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Slide from: SP_Навигатор_по_мерам_гос_поддержки_2024_74_стр.pdf
# Page: 73
# --------------------------------------------------------------------------------
# Best matching chunk (topic_overview):
# Distance: 0.568
# --------------------------------------------------------------------------------
# Тема: Презентация компании Strategy Partners
# Цель: Подчеркнуть достижения и опыт компании в области стратегического консалтинга
# Ключевая информация: Основные факты о команде, партнерствах и проектах.
#
# Chunk distances:
# --------------------------------------------------------------------------------
# text_content: not matched
# visual_content: not matched
# topic_overview: 0.568
# conclusions_and_insights: not matched
# layout_and_composition: not matched
#
# Full slide content:
# --------------------------------------------------------------------------------
#
# text_content:
# ...

# %%
results = storage.search_query_presentations(
    "Презентация про экономику Китая",
)
display_search_result_page(results[0].best_slide)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Slide from: ЯиП_Энергетический_переход_Вызовы_и_возможности_для_России.pdf
# Page: 12
# --------------------------------------------------------------------------------
# Best matching chunk (topic_overview):
# Distance: 0.549
# --------------------------------------------------------------------------------
# Тема: Инвестиции в технологии энергоперехода
# Цель: Показать необходимость увеличения инвестиций для достижения целей NZE
# Ключевая информация: Объемы инвестиций в различные источники энергии и их влияние на экономику.
#
# Chunk distances:
# --------------------------------------------------------------------------------
# text_content: not matched
# visual_content: not matched
# topic_overview: 0.549
# conclusions_and_insights: not matched
# layout_and_composition: not matched
#
# Full slide content:
# --------------------------------------------------------------------------------
#
# ...

# %%
results = storage.search_query_presentations(
    "Зоомагазины",
)
display_search_result_page(results[0].best_slide)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Slide from: dodo-brands-monthly-trading-update-sep-2024.pdf
# Page: 3
# --------------------------------------------------------------------------------
# Best matching chunk (text_content):
# Distance: 0.597
# --------------------------------------------------------------------------------
# Заголовок: "Поток роста сети"
#
# Основные данные:
# - Существующие магазины: 1179
# - Магазины в стадии строительства: +231
# - Оставшиеся запланированные магазины: +678
# - Всего существующих и запланированных магазинов: 2088
#
# Примечание: данные на 30 сентября 2024 года
#
# Chunk distances:
# --------------------------------------------------------------------------------
# text_content: 0.638
# visual_content: not matched
# topic_overview: 0.662
# conclusions_and_insights: 0.654
# layout_and_composition: not matched
#
# Full slide content:
# ...

# %%
results = storage.search_query_presentations(
    "Фиолетовый цвет",
)
display_search_result_page(results[0].best_slide)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Slide from: 2.Kolmogorov Arnold Networks_Павел Плюснин_вер.2.pdf
# Page: 39
# --------------------------------------------------------------------------------
# Best matching chunk (visual_content):
# Distance: 0.503
# --------------------------------------------------------------------------------
# Фон слайда градиентного фиолетового цвета. В центре слайда изображена иконка шестеренки, направленная вверх и в стороны,
#  символизирующая процесс масштабирования. Иконка выполнена в светло-фиолетовом цвете, что создает контраст с фоном.
# Номер слайда (39) расположен в правом нижнем углу, выполнен в белом цвете.
#
# Chunk distances:
# --------------------------------------------------------------------------------
# text_content: not matched
# visual_content: 0.503
# topic_overview: not matched
# conclusions_and_insights: not matched
# layout_and_composition: 0.650
#
# Full slide content:
# ...

# %%
results = storage.search_query_presentations(
    "Котики",
)
display_search_result_page(results[0].best_slide)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Slide from: 4.Люди не нужны_Данила Бочарников_вер.3.pdf
# Page: 5
# --------------------------------------------------------------------------------
# Best matching chunk (visual_content):
# Distance: 0.646
# --------------------------------------------------------------------------------
# Таблица с тремя колонками: 'Rank', 'Запрос', 'Поиски'. Заголовки таблицы выделены синим цветом. Вторая строка таблицы
# имеет светло-синий фон для акцента. Справа от таблицы размещены изображения котят с описанием и ценами. Изображения
# имеют рамки и небольшие иконки для взаимодействия.
#
# Chunk distances:
# --------------------------------------------------------------------------------
# text_content: 0.724
# visual_content: 0.646
# topic_overview: not matched
# conclusions_and_insights: 0.723
# layout_and_composition: not matched
#
# Full slide content:
# ...

# %%
results = storage.search_query_presentations(
    "Фото кабриолета",
)
display_search_result_page(results[0].best_slide)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Slide from: SP_Навигатор_по_мерам_гос_поддержки_2024_74_стр.pdf
# Page: 62
# --------------------------------------------------------------------------------
# Best matching chunk (visual_content):
# Distance: 0.567
# --------------------------------------------------------------------------------
# На слайде изображен интерьер кабины пилота самолета, что подчеркивает тематику авиации. Фоновое изображение занимает
# левую часть слайда, в то время как текстовые элементы расположены на правой стороне слайда в белом блоке с синей рамкой.
#  Логотип "Strategy Partners" расположен внизу справа, а также присутствует ссылка на сайт внизу слайда.
#
# Chunk distances:
# --------------------------------------------------------------------------------
# text_content: not matched
# visual_content: 0.567
# topic_overview: not matched
# conclusions_and_insights: not matched
# layout_and_composition: not matched
# ...

# %%
results = storage.search_query_presentations(
    "The capital of Great Britain",
)
display_search_result_page(results[0].best_slide)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Slide from: 1.Разметка датасетов в эпоху мультимодальности_Дмитрий Антипов_вер.4.pdf
# Page: 69
# --------------------------------------------------------------------------------
# Best matching chunk (text_content):
# Distance: 0.857
# --------------------------------------------------------------------------------
# Основной заголовок: "LLM — новый король"
# Подзаголовок: "И почему часть разметки мы уже делаем через LLM"
#
# Стилизация текста: заголовок выполнен крупным шрифтом темно-синего цвета, подзаголовок — меньшим шрифтом светло-голубого
#  цвета, что создает контраст и акцентирует внимание на главной теме слайда.
#
# Chunk distances:
# --------------------------------------------------------------------------------
# text_content: 0.857
# visual_content: not matched
# topic_overview: not matched
# conclusions_and_insights: not matched
# layout_and_composition: not matched
#
# ...

# %%
results = storage.search_query_presentations(
    "Обучение LLM на CPU",
)
display_search_result_page(results[0].best_slide)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Slide from: 1.Разметка датасетов в эпоху мультимодальности_Дмитрий Антипов_вер.4.pdf
# Page: 70
# --------------------------------------------------------------------------------
# Best matching chunk (conclusions_and_insights):
# Distance: 0.439
# --------------------------------------------------------------------------------
# Основные выводы:
# - LLM могут значительно упростить процесс решения задач.
# - Снижение затрат на предразметку делает технологии более доступными.
# - LLM могут конкурировать с людьми в простых задачах.
#
# Chunk distances:
# --------------------------------------------------------------------------------
# text_content: 0.517
# visual_content: not matched
# topic_overview: 0.450
# conclusions_and_insights: 0.439
# layout_and_composition: not matched
#
# Full slide content:
# --------------------------------------------------------------------------------
#
# ...

# %%
results = storage.search_query_presentations(
    "Обучение в школе",
)
display_search_result_page(results[0].best_slide)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Slide from: 2.Kolmogorov Arnold Networks_Павел Плюснин_вер.2.pdf
# Page: 29
# --------------------------------------------------------------------------------
# Best matching chunk (topic_overview):
# Distance: 0.672
# --------------------------------------------------------------------------------
# Тема: Высокая интерпретируемость в машинном обучении
# Цель: Показать процесс обучения и обрезки в модели
# Ключевая информация: Два шага, которые улучшают интерпретируемость модели.
#
# Chunk distances:
# --------------------------------------------------------------------------------
# text_content: not matched
# visual_content: not matched
# topic_overview: 0.672
# conclusions_and_insights: not matched
# layout_and_composition: not matched
#
# Full slide content:
# --------------------------------------------------------------------------------
#
# text_content:
# ...

# %%
results = storage.search_query_presentations(
    "Красный цвет",
)
display_search_result_page(results[0].best_slide)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Slide from: 3.Разметка будущего как GPT помогает обучать модели_Герман Ганус_вер.4.pdf
# Page: 26
# --------------------------------------------------------------------------------
# Best matching chunk (visual_content):
# Distance: 0.656
# --------------------------------------------------------------------------------
# Слайд имеет светлый фон с легким оттенком. Блок с пометкой "Промт" расположен в верхней части слайда, выделен розовым
# цветом. Вопросы расположены ниже, каждый из них выделен зеленым цветом, что помогает акцентировать внимание на ключевых
# моментах. Общая компоновка слайда создает легкость восприятия информации.
#
# Chunk distances:
# --------------------------------------------------------------------------------
# text_content: not matched
# visual_content: 0.656
# topic_overview: not matched
# conclusions_and_insights: not matched
# layout_and_composition: not matched
#
# ...

# %%
results = storage.search_query_presentations(
    "История Российской Империи",
)
display_search_result_page(results[0].best_slide)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Slide from: ЯиП_Энергетический_переход_Вызовы_и_возможности_для_России.pdf
# Page: 27
# --------------------------------------------------------------------------------
# Best matching chunk (conclusions_and_insights):
# Distance: 0.715
# --------------------------------------------------------------------------------
# Основные выводы:
# - Необходимость адаптации к изменениям в энергетическом ландшафте
# - Важность понимания вызовов и возможностей для России
# - Стратегические императивы для эффективного планирования.
#
# Chunk distances:
# --------------------------------------------------------------------------------
# text_content: not matched
# visual_content: not matched
# topic_overview: not matched
# conclusions_and_insights: 0.715
# layout_and_composition: not matched
#
# Full slide content:
# --------------------------------------------------------------------------------
#
# ...

# %%
results = storage.search_query_presentations(
    "Презентация про кофе",
)
display_search_result_page(results[0].best_slide)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Slide from: SP_Навигатор_по_мерам_гос_поддержки_2024_74_стр.pdf
# Page: 64
# --------------------------------------------------------------------------------
# Best matching chunk (topic_overview):
# Distance: 0.495
# --------------------------------------------------------------------------------
# Тема: Привлечение льготного финансирования для проекта по производству чая и специй.
# Цель: Представить ключевые аспекты проекта и его результаты.
# Ключевая информация: Описание компании, цели, задачи и результаты проекта.
#
# Chunk distances:
# --------------------------------------------------------------------------------
# text_content: 0.607
# visual_content: not matched
# topic_overview: 0.495
# conclusions_and_insights: not matched
# layout_and_composition: not matched
#
# Full slide content:
# --------------------------------------------------------------------------------
#
# text_content:
# ...

# %%
results = storage.search_query_presentations(
    "",
)
display_search_result_page(results[0].best_slide)
